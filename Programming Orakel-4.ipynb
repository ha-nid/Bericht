# %% [markdown]
# # Hallo!
# Herzlich Willkommen. Ich bin das allwissende Orakel, dass dir hilft heute eine Entscheidung zu treffen.

# %%
from time import sleep
Name = input("Wie ist dein Name?:")

# %%
sleep (2)
print("Hallo",Name,"! Schön dich kennen zu lernen!")
sleep (2)
print ("Hast du eine Frage die dich heute beschäftigt?")
sleep (1)
Frage = input ("Deine Frage:")
Frage = Frage

# %%
print ("Das ist eine gute Frage..")
sleep (3)
print ("Lass mich mal überlegen.")

# %%
sleep (3)
print ("Um dir eine genaue Antwort geben zu können, muss ich noch dein Alter wissen.")

# %%
sleep(1)
Alter = input ("Dein Alter:")
print ("Du bist also", Alter, "Jahre alt.")
sleep (3)
print ("Interessant..")

# %%
sleep (3)
print("Langsam komme ich der Antwort näher.")
print("Aber um mir sicher zu sein, brauche ich noch dein Sternzeichen.")
sleep(1)
Sternzeichen = input("Dein Sternzeichen:")
print("Aaah, du gehörst also zum Sternzeichen",Sternzeichen,". Das erklärt schonmal einiges.")

# %% [markdown]
# # Für später gespeichert:

# %%
import random
Antwort = ('Ja','Nein','Vielleicht','Dein Handeln wird die Dinge besser machen','Du solltest nicht darauf setzen','Befolge den Rat eines Fachmanns','Konzentriere dich auf dein Privatleben','Sicher','Es lässt sich nicht vorhersagen','Mit Sicherheit nicht','Geh es mit spielerischer Neugierde an','Warte besser','Behalte es für dich','Es könnte zu überraschenden Ergebnissen führen','Die Antwort erhältst du auf andere Art und Weise','Du wirst dich anpassen müssen','Es wird dir Glück bringen','Hab Geduld','Du wirst alles erfahren, was du wissen musst','Es steht in wichtigem Zusammenhang mit anderen Situationen','Sieh zu, was passiert','Du wirst froh sein, dass du es getan hast','Lass es dir schriftlich geben','Im Moment ungünstig','Wenn du tust, was dir gesagt wird','Verlang im Moment nicht mehr')
def selectRandom(Antwort):
    return random.choice(Antwort)
print("Du hast gefragt:",Frage)
print("Ich sage:",selectRandom(Antwort))
# Out:
# Du hast gefragt: Bin ich dumm?
# Ich sage: Du solltest nicht darauf setzen
