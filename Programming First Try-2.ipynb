# %% [markdown]
# # Hallo!
# Herzlich Willkommen. Ich bin das Orakel und ich helfe dir Antworten auf Fragen zu finden, die dich beschäftigen.

# %% [markdown]
# Stelle mir eine Frage die mit Ja oder Nein beantwortet werden kann:

# %%
from tkinter import *
fenster = Tk()
fenster.mainloop()
